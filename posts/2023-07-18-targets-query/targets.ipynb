# %%
# import packages
import requests, json
import pandas as pd

# %%
# Force return from the server in JSON format
headers = {'accept': 'application/json'}
 
# This URL locates the ENCODE biosample with accession number ENCBS000AAA
url = 'https://www.encodeproject.org/files/ENCFF991ND/?format=json'
 
# GET the object
response = requests.get(url, headers=headers)
 
# Extract the JSON response as a Python dictionary
encff = response.json()

# encff['biosample_ontology']['system_slims']
encff
# Out:
# {'@type': ['HTTPNotFound', 'Error'],
#  'status': 'error',
#  'code': 404,
#  'title': 'Not Found',
#  'description': 'The resource could not be found.',
#  'detail': '/files/ENCFF991ND/'}

# %%
# get og df
# loop over IDs and get each slim

# %%
# get original targets df
targets_txt = 'https://raw.githubusercontent.com/calico/basenji/master/manuscripts/cross2020/targets_human.txt'
df = pd.read_csv(targets_txt, sep='\t')

# %%
def get_json(id):
    headers = {'accept': 'application/json'}
    url = f'https://www.encodeproject.org/files/{id}/?format=json'
    response = requests.get(url, headers=headers)
    encff = response.json()
    return encff

# %%
# Make a dictionary of all encffs (only first time)
 
encffs = {}
for id in df['identifier']:
    encffs[id] = get_json(id)

# %%
# Save encffs to a file
with open('/Users/lauvav/Desktop/deep-learning/encffs.json', 'w') as file:
    json.dump(encffs, file, indent=4)

# %%
# Load the variable from the saved encffs file

# with open('variable.json', 'r') as file:
#     loaded_variable = json.load(file)

# %%
def get_slims(id):
    encff = encffs[id]
    system = 'NA'
    cell = 'NA'
    organ = 'NA'
    developmental = 'NA'
    
    try:
        bio_ont = encff['biosample_ontology']
        system_list = bio_ont['system_slims']
        cell_list = bio_ont['cell_slims']
        organ_list = bio_ont['organ_slims']
        developmental_list = bio_ont['developmental_slims']
    
        system = ', '.join(system_list)
        cell = ', '.join(cell_list)
        organ = ', '.join(organ_list)
        developmental = ', '.join(developmental_list)
    except KeyError:
        pass
    
    return [system, cell, organ, developmental]

# %%
for index, row in df.iterrows():
    system, cell, organ, dev = get_slims(row['identifier'])

    df.at[index, 'system_slims'] = system
    df.at[index, 'cell_slims'] = cell
    df.at[index, 'organ_slims'] = organ
    df.at[index, 'developmental_slims'] = dev

# %%
df[5000:5010]
# Out:
#       index  genome identifier  \
# 5000   5000       0  CNhs11833
# 5001   5001       0  CNhs11834
# 5002   5002       0  CNhs11835
# 5003   5003       0  CNhs11836
# 5004   5004       0  CNhs11837
# 5005   5005       0  CNhs11838
# 5006   5006       0  CNhs11840
# 5007   5007       0  CNhs11841
# 5008   5008       0  CNhs11842
# 5009   5009       0  CNhs11843
#
#                                                    file  clip  scale sum_stat  \
# 5000  /home/drk/tillage/datasets/human/cage/fantom/C...   384      1      sum
# 5001  /home/drk/tillage/datasets/human/cage/fantom/C...   384      1      sum
# 5002  /home/drk/tillage/datasets/human/cage/fantom/C...   384      1      sum
# 5003  /home/drk/tillage/datasets/human/cage/fantom/C...   384      1      sum
# 5004  /home/drk/tillage/datasets/human/cage/fantom/C...   384      1      sum
# 5005  /home/drk/tillage/datasets/human/cage/fantom/C...   384      1      sum
# 5006  /home/drk/tillage/datasets/human/cage/fantom/C...   384      1      sum
# 5007  /home/drk/tillage/datasets/human/cage/fantom/C...   384      1      sum
# 5008  /home/drk/tillage/datasets/human/cage/fantom/C...   384      1      sum
# 5009  /home/drk/tillage/datasets/human/cage/fantom/C...   384      1      sum
#
#                                             description system_slims  \
# 5000              CAGE:chondrosarcoma cell line:SW 1353           NA
# 5001                 CAGE:carcinoid cell line:NCI-H1770           NA
# 5002              CAGE:osteoclastoma cell line:Hs 706.T           NA
# 5003            CAGE:Ewing's sarcoma cell line:Hs 863.T           NA
# 5004  CAGE:transitional cell carcinoma cell line:Hs ...           NA
# 5005     CAGE:alveolar cell carcinoma cell line:SW 1573           NA
# 5006  CAGE:bronchioalveolar carcinoma cell line:NCI-...           NA
# 5007    CAGE:bronchogenic carcinoma cell line:ChaGo-K-1           NA
# 5008    CAGE:fibrous histiocytoma cell line:GCT TIB-223           NA
# 5009              CAGE:hairy cell leukemia cell line:Mo           NA
#
#      cell_slims organ_slims developmental_slims
# 5000         NA          NA                  NA
# 5001         NA          NA                  NA
# 5002         NA          NA                  NA
# 5003         NA          NA                  NA
# 5004         NA          NA                  NA
# 5005         NA          NA                  NA
# 5006         NA          NA                  NA
# 5007         NA          NA                  NA
# 5008         NA          NA                  NA
# 5009         NA          NA                  NA

# %%
# Makes columns for one ind
# df.at[2, 'system_slims'] = add_system(df.at[2, 'identifier'])

# Make columns for a list of inds
# row_indices = range(10)
# for row_index in row_indices:
#     system, cell, organ, dev = get_slims(df.at[row_index, 'identifier'])

#     df.loc[row_index, 'system_slims'] = system
#     df.loc[row_index, 'cell_slims'] = cell
#     df.loc[row_index, 'organ_slims'] = organ
#     df.loc[row_index, 'developmental_slims'] = dev
